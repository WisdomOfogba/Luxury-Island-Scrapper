# %% [markdown]
# # Island Luxury Data set

# %%
import pandas as pd
df = pd.read_csv('Island_Luxury_Data.csv')

# %% [markdown]
# ## Displaying the Data

# %%
df
# Out:
#                                                   title  \
# 0     Fully Serviced 3-bedroom Apartment With Study ...
# 1     Top Rated Luxury 2 Bedroom Penthouse Apartment...
# 2                            Luxury 3 Bedroom Apartment
# 3                  Luxury 3 Bedroom Apartment 4th Floor
# 4            Well Maintained Luxury 4 Bedroom Apartment
# ...                                                 ...
# 3227          Exclusive Residences  2 Bedroom Apartment
# 3228                Fully Serviced 2 Bedroom Maisonette
# 3229  4 Bedrooms Flat With No Bq For Office Use Only...
# 3230  Fully Serviced 2 Bedroom Maisonette High Rise ...
# 3231  Fully Serviced 2 Bedrooms High Rise Maisonette...
#
#                                                location  \
# 0                               Old Ikoyi, Ikoyi, Lagos
# 1                         Old Ikoyi Lagos, Ikoyi, Lagos
# 2                                          Ikoyi, Lagos
# 3                           Banana Island, Ikoyi, Lagos
# ...
