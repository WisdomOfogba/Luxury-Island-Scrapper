# %% [markdown]
# # Island Luxury Data set

# %%
import pandas as pd
df = pd.read_csv('Island_Luxury_Data.csv')
# Out:
# Running cells with 'venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/sanyaolu/Documents/dev/freelance-projects/backend/scrape-props/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ## Displaying the Data

# %%
df
